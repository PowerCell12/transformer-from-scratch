# %%
import numpy as np

# %%
def ReLU(layer):
    return np.maximum(0, layer)

def feed_forward(X, W1, b1, W2, b2):
    inner_layer = ReLU(np.dot(X, W1) + b1)

    return np.dot(inner_layer, W2) + b2

# %%
d_model=4
d_ff=d_model * 4

np.random.seed(42)
W1 = np.random.randn(d_model, d_ff)
b1 = np.random.randn(d_ff)
W2 = np.random.randn(d_ff, d_model)
b2 = np.random.randn(d_model)

x = np.array([1, 0, 1, 0], dtype=float)
print(feed_forward(x, W1, b1, W2, b2))
print(feed_forward(x, W1, b1, W2, b2).shape)
# Out:
# [-1.19916701 -0.36501703 -0.69145771 -0.78174665]
# (4,)
